# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download goyaladi/flight-dataset
# Out:
# ...
#   0% 0.00/8.87k [00:00<?, ?B/s]
# 100% 8.87k/8.87k [00:00<00:00, 17.2MB/s]

# %%
! unzip flight-dataset
# Out:
# Archive:  flight-dataset.zip
#   inflating: Flight_data.csv

# %%
#Import Statements
import numpy as np #computation and arrays
import seaborn as sns #advanced charts and graphs
import pandas as pd #Dataframe handling
import matplotlib.pyplot as plt #graphs and charts

# %%
df = pd.read_csv("/content/Flight_data.csv")

# %%
df.head()
# Out:
#        Departure City    Arrival City       Departure Date  Flight Duration  \
# 0          Wilsonstad  Lake Johnmouth  2023-05-02 20:11:09          1.27581
# 1           New Brent      Port Wanda  2023-04-21 00:10:14          1.27581
# 2  South Samanthaberg  Lake Meganside  2023-05-12 15:16:31          0.72111
# 3      Lake Gracefurt       Jamesberg  2023-06-13 20:53:09         -0.94299
# 4         Owenborough     Kelleymouth  2023-05-15 23:06:14         -0.38829
#
#    Delay Minutes  Customer ID               Name Booking Class  \
# 0            120         3769      Daniel Oliver      Business
# 1             35         3529       Deborah Hall       Economy
# 2             67         1303          Mary York       Economy
# 3             72         2965  Christina Sanchez       Economy
# 4            101         8779       Dustin Owens       Economy
#
#   Frequent Flyer Status    Route  Ticket Price  Competitor Price    Demand  \
# ...

# %%
df.tail()
# Out:
#        Departure City        Arrival City       Departure Date  \
# 95    Brittneychester      South Patricia  2023-06-07 01:09:54
# 96  South Staceyhaven        West Kenneth  2023-05-19 23:13:31
# 97         Arnoldtown           Morriston  2023-05-22 11:51:34
# 98        Murrayhaven  Lake Jennifermouth  2023-05-27 21:15:35
# 99         Butlerside    East Morganburgh  2023-06-03 14:46:08
#
#     Flight Duration  Delay Minutes  Customer ID              Name  \
# 95        -1.497691             15         6848  Brittney Swanson
# 96        -1.497691             84         3724   Jessica Johnson
# 97         0.166410              8         8395     Amber Mcclure
# 98        -0.942990              7         4142         Lisa Luna
# 99         0.721110              1         1017    Jeffrey Turner
#
#    Booking Class Frequent Flyer Status    Route  Ticket Price  \
# 95       Economy                Silver  SYD-MEL    210.236193
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Departure City         100 non-null    object
#  1   Arrival City           100 non-null    object
#  2   Departure Date         100 non-null    object
#  3   Flight Duration        100 non-null    float64
#  4   Delay Minutes          100 non-null    int64
#  5   Customer ID            100 non-null    int64
#  6   Name                   100 non-null    object
#  7   Booking Class          100 non-null    object
#  8   Frequent Flyer Status  100 non-null    object
#  9   Route                  100 non-null    object
#  10  Ticket Price           100 non-null    float64
#  11  Competitor Price       100 non-null    float64
#  12  Demand                 100 non-null    float64
#  13  Origin                 100 non-null    object
# ...

# %%
df.describe() #Gives Descriptive Statistics
# Out:
#        Flight Duration  Delay Minutes  Customer ID  Ticket Price  \
# count     1.000000e+02     100.000000   100.000000    100.000000
# mean     -1.387779e-16      57.900000  5164.630000    303.337169
# std       1.005038e+00      33.195929  2626.451593    119.160993
# min      -1.497691e+00       1.000000  1010.000000    114.529016
# 25%      -9.429903e-01      33.750000  3090.500000    191.771980
# 50%       1.664101e-01      57.000000  4922.000000    297.944962
# 75%       8.597853e-01      81.500000  7202.750000    412.563311
# max       1.275810e+00     120.000000  9861.000000    498.549369
#
#        Competitor Price        Demand  Profitability  Loyalty Points
# count        100.000000  1.000000e+02     100.000000      100.000000
# mean         292.867827 -1.776357e-16       1.031524     2390.420000
# std          113.418380  1.005038e+00       0.273866     1522.693017
# min           93.418926 -1.660900e+00       0.515533       45.000000
# ...

# %%
df.shape
# Out:
# (100, 18)

# %%
#Feature Engineering
Avg_ticket_price = df.groupby('Ticket Price').mean(numeric_only = True)
Avg_delay_min = df.groupby('Delay Minutes').mean(numeric_only = True)

# %%
Avg_ticket_price.head()
# Out:
#               Flight Duration  Delay Minutes  Customer ID  Competitor Price  \
# Ticket Price
# 114.529016            1.27581           35.0       3529.0        394.583641
# 116.490246            0.16641           48.0       2957.0        419.326372
# 117.430166            1.27581           44.0       9861.0        250.707580
# 123.967678            0.16641           67.0       2165.0        151.648804
# 126.168809            1.27581           94.0       4338.0        225.741490
#
#                 Demand  Profitability  Loyalty Points  Churned
# Ticket Price
# 114.529016   -1.005569       1.265026           833.0      1.0
# 116.490246    1.567212       0.890094          4764.0      0.0
# 117.430166   -0.325967       1.032098           234.0      0.0
# 123.967678    0.572080       0.689366          1893.0      1.0
# 126.168809    0.596351       1.084220          4322.0      1.0

# %%
Avg_delay_min.head()
# Out:
#                Flight Duration  Customer ID  Ticket Price  Competitor Price  \
# Delay Minutes
# 1                      0.72111       1017.0    168.629774        425.605440
# 5                      0.44376       6008.0    328.180469        312.864166
# 6                      0.16641       2647.5    278.824145        158.570775
# 7                     -0.94299       4142.0    457.453579        280.391721
# 8                      0.44376       6402.5    450.331578        274.133250
#
#                  Demand  Profitability  Loyalty Points  Churned
# Delay Minutes
# 1              0.086649       0.908496          4950.0      0.0
# 5              0.171600       1.088748          3479.0      0.5
# 6             -0.362374       1.031990          3007.0      1.0
# 7              0.741980       1.483030          1328.0      1.0
# 8             -0.641496       0.990861          3162.0      1.0

# %%
df.isnull().sum()
# Out:
# Departure City           0
# Arrival City             0
# Departure Date           0
# Flight Duration          0
# Delay Minutes            0
# Customer ID              0
# Name                     0
# Booking Class            0
# Frequent Flyer Status    0
# Route                    0
# Ticket Price             0
# Competitor Price         0
# Demand                   0
# Origin                   0
# Destination              0
# Profitability            0
# Loyalty Points           0
# Churned                  0
# dtype: int64

# %%
df.dropna()  # Drop rows with missing values
# Out:
#         Departure City        Arrival City       Departure Date  \
# 0           Wilsonstad      Lake Johnmouth  2023-05-02 20:11:09
# 1            New Brent          Port Wanda  2023-04-21 00:10:14
# 2   South Samanthaberg      Lake Meganside  2023-05-12 15:16:31
# 3       Lake Gracefurt           Jamesberg  2023-06-13 20:53:09
# 4          Owenborough         Kelleymouth  2023-05-15 23:06:14
# ..                 ...                 ...                  ...
# 95     Brittneychester      South Patricia  2023-06-07 01:09:54
# 96   South Staceyhaven        West Kenneth  2023-05-19 23:13:31
# 97          Arnoldtown           Morriston  2023-05-22 11:51:34
# 98         Murrayhaven  Lake Jennifermouth  2023-05-27 21:15:35
# 99          Butlerside    East Morganburgh  2023-06-03 14:46:08
#
#     Flight Duration  Delay Minutes  Customer ID               Name  \
# 0          1.275810            120         3769      Daniel Oliver
# ...

# %%
df['Ticket Price'].sum()
# Out:
# 30333.716947201076

# %%
df['Ticket Price'].mean()
# Out:
# 303.33716947201077

# %%
max_value = np.max(df['Ticket Price'])
max_value
# Out:
# 498.5493692899824

# %%
min_value = np.min(df['Ticket Price'])
min_value
# Out:
# 114.52901630896034

# %%
#Correlation Matrix
correlation_matrix = df.corr(numeric_only = True)

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.histplot(x='Demand', data=df, bins=10)
# Out:
# <Axes: xlabel='Demand', ylabel='Count'>

# %% [markdown]
# Scatter plots are the graphs that present the relationship between two variables in a data-set. It represents data points on a two-dimensional plane or on a Cartesian system. The independent variable or attribute is plotted on the X-axis, while the dependent variable is plotted on the Y-axis.
#
# *   Independent - Demand
# *   Dependent - Profitability

# %%
sns.scatterplot(x='Demand', y='Profitability', data=df)
# Out:
# <Axes: xlabel='Demand', ylabel='Profitability'>

# %%
sns.countplot(x='Booking Class', data=df)
# Out:
# <Axes: xlabel='Booking Class', ylabel='count'>

# %%
sns.countplot(x='Frequent Flyer Status', data=df)
# Out:
# <Axes: xlabel='Frequent Flyer Status', ylabel='count'>

# %%
sns.boxplot(x='Flight Duration', data=df)
# Out:
# <Axes: xlabel='Flight Duration'>

# %%
sns.barplot(x='Ticket Price',y='Competitor Price',data=df)
# Out:
# <Axes: xlabel='Ticket Price', ylabel='Competitor Price'>
